# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import pyarrow.parquet as pq
import pyarrow as pa
import os

# %%
chile_df = pd.read_csv('data/chile.csv',  low_memory=False)
argentina_df = pd.read_csv('data/argentina.csv',  low_memory=False)
antartica_df = pd.read_csv('data/antartica.csv',  low_memory=False)

dataframes = {
    'Chile': chile_df,
    'Argentina': argentina_df,
    'Antártica': antartica_df
}

for name, df in dataframes.items():
    print(f"DataFrame: {name}")
    print(f"Número de columnas: {len(df.columns)}")
    print("Información de las columnas:")
    print(df.info(5))
    print("\n")
# Out:
# DataFrame: Chile
# Número de columnas: 146
# Información de las columnas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9481 entries, 0 to 9480
# Data columns (total 146 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    occurrence_no        int64
#  1    record_type          object
#  2    reid_no              float64
#  3    flags                object
#  4    collection_no        int64
#  5    accepted_name        object
#  6    accepted_attr        float64
#  7    accepted_rank        object
#  8    accepted_no          float64
#  9    early_interval       object
#  10   late_interval        object
#  11   max_ma               float64
#  12   min_ma               float64
#  13   ref_author           object
#  14   ref_pubyr            int64
#  15   reference_no         int64
#  16   phylum               object
#  17   phylum_no            object
#  18   class                object
#  19   class_no             object
#  20   order                object
#  21   order_no             object
#  22   family               object
#  23   family_no            object
#  24   genus                object
#  25   genus_no             object
#  26   subgenus_no          float64
#  27   primary_name         object
#  28   primary_reso         object
#  29   subgenus_name        object
#  30   subgenus_reso        object
#  31   species_name         object
#  32   species_reso         object
#  33   image_no             float64
#  34   plant_organ          object
#  35   plant_organ2         float64
#  36   abund_value          object
#  37   abund_unit           object
#  38   taxon_environment    object
#  39   environment_basis    object
#  40   motility             object
#  41   motility_basis       object
#  42   life_habit           object
#  43   life_habit_basis     object
#  44   vision               object
#  45   vision_basis         object
#  46   diet                 object
#  47   diet_basis           object
#  48   reproduction         object
#  49   reproduction_basis   object
#  50   ontogeny             object
#  51   ontogeny_basis       object
#  52   ecospace_comments    object
#  53   composition          object
#  54   architecture         object
#  55   thickness            object
#  56   reinforcement        object
#  57   taphonomy_basis      object
#  58   lng                  float64
#  59   lat                  float64
#  60   cc                   object
#  61   state                object
#  62   county               object
#  63   latlng_basis         object
#  64   latlng_precision     object
#  65   geogscale            object
#  66   geogcomments         object
#  67   paleomodel           object
#  68   geoplate             object
#  69   paleoage             object
#  70   paleolng             float64
#  71   paleolat             float64
#  72   paleomodel2          object
#  73   geoplate2            object
#  74   paleoage2            object
#  75   paleolng2            float64
#  76   paleolat2            float64
#  77   paleomodel3          object
#  78   geoplate3            object
#  79   paleoage3            object
#  80   paleolng3            float64
#  81   paleolat3            float64
#  82   formation            object
#  83   stratgroup           object
#  84   member               object
#  85   formation.1          object
#  86   stratgroup.1         object
#  87   member.1             object
#  88   stratscale           object
#  89   zone                 object
#  90   localsection         object
#  91   localbed             object
#  92   localbedunit         object
#  93   localorder           object
#  94   regionalsection      float64
#  95   regionalbed          float64
#  96   regionalbedunit      float64
#  97   regionalorder        float64
#  98   stratcomments        object
#  99   lithdescript         object
#  100  lithology1           object
#  101  lithadj1             object
#  102  lithification1       object
#  103  minor_lithology1     object
#  104  fossilsfrom1         object
#  105  lithology2           object
#  106  lithadj2             object
#  107  lithification2       object
#  108  minor_lithology2     object
#  109  fossilsfrom2         object
#  110  lithdescript.1       object
#  111  lithology1.1         object
#  112  lithadj1.1           object
#  113  lithification1.1     object
#  114  minor_lithology1.1   object
#  115  fossilsfrom1.1       object
#  116  lithology2.1         object
#  117  lithadj2.1           object
#  118  lithification2.1     object
#  119  minor_lithology2.1   object
#  120  fossilsfrom2.1       object
#  121  environment          object
#  122  tectonic_setting     object
#  123  geology_comments     object
#  124  time_bins            object
#  125  time_contain         object
#  126  time_major           object
#  127  time_buffer          object
#  128  time_overlap         object
#  129  collection_type      object
#  130  collection_methods   object
#  131  museum               object
#  132  collection_coverage  object
#  133  collection_size      object
#  134  rock_censused        object
#  135  collectors           object
#  136  collection_dates     object
#  137  collection_comments  object
#  138  taxonomy_comments    object
#  139  primary_reference    object
#  140  authorizer_no        int64
#  141  enterer_no           int64
#  142  modifier_no          int64
#  143  authorizer           object
#  144  enterer              object
#  145  modifier             object
# dtypes: float64(20), int64(7), object(119)
# memory usage: 10.6+ MB
# None
#
#
# DataFrame: Argentina
# Número de columnas: 146
# Información de las columnas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31881 entries, 0 to 31880
# Data columns (total 146 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    occurrence_no        int64
#  1    record_type          object
#  2    reid_no              float64
#  3    flags                object
#  4    collection_no        int64
#  5    accepted_name        object
#  6    accepted_attr        float64
#  7    accepted_rank        object
#  8    accepted_no          float64
#  9    early_interval       object
#  10   late_interval        object
#  11   max_ma               float64
#  12   min_ma               float64
#  13   ref_author           object
#  14   ref_pubyr            int64
#  15   reference_no         int64
#  16   phylum               object
#  17   phylum_no            object
#  18   class                object
#  19   class_no             object
#  20   order                object
#  21   order_no             object
#  22   family               object
#  23   family_no            object
#  24   genus                object
#  25   genus_no             object
#  26   subgenus_no          float64
#  27   primary_name         object
#  28   primary_reso         object
#  29   subgenus_name        object
#  30   subgenus_reso        object
#  31   species_name         object
#  32   species_reso         object
#  33   image_no             float64
#  34   plant_organ          object
#  35   plant_organ2         object
#  36   abund_value          object
#  37   abund_unit           object
#  38   taxon_environment    object
#  39   environment_basis    object
#  40   motility             object
#  41   motility_basis       object
#  42   life_habit           object
#  43   life_habit_basis     object
#  44   vision               object
#  45   vision_basis         object
#  46   diet                 object
#  47   diet_basis           object
#  48   reproduction         object
#  49   reproduction_basis   object
#  50   ontogeny             object
#  51   ontogeny_basis       object
#  52   ecospace_comments    object
#  53   composition          object
#  54   architecture         object
#  55   thickness            object
#  56   reinforcement        object
#  57   taphonomy_basis      object
#  58   lng                  float64
#  59   lat                  float64
#  60   cc                   object
#  61   state                object
#  62   county               object
#  63   latlng_basis         object
#  64   latlng_precision     object
#  65   geogscale            object
#  66   geogcomments         object
#  67   paleomodel           object
#  68   geoplate             object
#  69   paleoage             object
#  70   paleolng             float64
#  71   paleolat             float64
#  72   paleomodel2          object
#  73   geoplate2            object
#  74   paleoage2            object
#  75   paleolng2            float64
#  76   paleolat2            float64
#  77   paleomodel3          object
#  78   geoplate3            object
#  79   paleoage3            object
#  80   paleolng3            float64
#  81   paleolat3            float64
#  82   formation            object
#  83   stratgroup           object
#  84   member               object
#  85   formation.1          object
#  86   stratgroup.1         object
#  87   member.1             object
#  88   stratscale           object
#  89   zone                 object
#  90   localsection         object
#  91   localbed             object
#  92   localbedunit         object
#  93   localorder           object
#  94   regionalsection      object
#  95   regionalbed          object
#  96   regionalbedunit      object
#  97   regionalorder        object
#  98   stratcomments        object
#  99   lithdescript         object
#  100  lithology1           object
#  101  lithadj1             object
#  102  lithification1       object
#  103  minor_lithology1     object
#  104  fossilsfrom1         object
#  105  lithology2           object
#  106  lithadj2             object
#  107  lithification2       object
#  108  minor_lithology2     object
#  109  fossilsfrom2         object
#  110  lithdescript.1       object
#  111  lithology1.1         object
#  112  lithadj1.1           object
#  113  lithification1.1     object
#  114  minor_lithology1.1   object
#  115  fossilsfrom1.1       object
#  116  lithology2.1         object
#  117  lithadj2.1           object
#  118  lithification2.1     object
#  119  minor_lithology2.1   object
#  120  fossilsfrom2.1       object
#  121  environment          object
#  122  tectonic_setting     object
#  123  geology_comments     object
#  124  time_bins            object
#  125  time_contain         object
#  126  time_major           object
#  127  time_buffer          object
#  128  time_overlap         object
#  129  collection_type      object
#  130  collection_methods   object
#  131  museum               object
#  132  collection_coverage  object
#  133  collection_size      object
#  134  rock_censused        object
#  135  collectors           object
#  136  collection_dates     object
#  137  collection_comments  object
#  138  taxonomy_comments    object
#  139  primary_reference    object
#  140  authorizer_no        int64
#  141  enterer_no           int64
#  142  modifier_no          int64
#  143  authorizer           object
#  144  enterer              object
#  145  modifier             object
# dtypes: float64(15), int64(7), object(124)
# memory usage: 35.5+ MB
# None
#
#
# DataFrame: Antártica
# Número de columnas: 146
# Información de las columnas:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11311 entries, 0 to 11310
# Data columns (total 146 columns):
#  #    Column               Dtype
# ---   ------               -----
#  0    occurrence_no        int64
#  1    record_type          object
#  2    reid_no              float64
#  3    flags                object
#  4    collection_no        int64
#  5    accepted_name        object
#  6    accepted_attr        float64
#  7    accepted_rank        object
#  8    accepted_no          float64
#  9    early_interval       object
#  10   late_interval        object
#  11   max_ma               float64
#  12   min_ma               float64
#  13   ref_author           object
#  14   ref_pubyr            int64
#  15   reference_no         int64
#  16   phylum               object
#  17   phylum_no            object
#  18   class                object
#  19   class_no             object
#  20   order                object
#  21   order_no             object
#  22   family               object
#  23   family_no            object
#  24   genus                object
#  25   genus_no             object
#  26   subgenus_no          float64
#  27   primary_name         object
#  28   primary_reso         object
#  29   subgenus_name        object
#  30   subgenus_reso        object
#  31   species_name         object
#  32   species_reso         object
#  33   image_no             float64
#  34   plant_organ          object
#  35   plant_organ2         object
#  36   abund_value          object
#  37   abund_unit           object
#  38   taxon_environment    object
#  39   environment_basis    object
#  40   motility             object
#  41   motility_basis       object
#  42   life_habit           object
#  43   life_habit_basis     object
#  44   vision               object
#  45   vision_basis         object
#  46   diet                 object
#  47   diet_basis           object
#  48   reproduction         object
#  49   reproduction_basis   object
#  50   ontogeny             object
#  51   ontogeny_basis       object
#  52   ecospace_comments    object
#  53   composition          object
#  54   architecture         object
#  55   thickness            object
#  56   reinforcement        object
#  57   taphonomy_basis      object
#  58   lng                  float64
#  59   lat                  float64
#  60   cc                   object
#  61   state                object
#  62   county               object
#  63   latlng_basis         object
#  64   latlng_precision     object
#  65   geogscale            object
#  66   geogcomments         object
#  67   paleomodel           object
#  68   geoplate             object
#  69   paleoage             object
#  70   paleolng             float64
#  71   paleolat             float64
#  72   paleomodel2          object
#  73   geoplate2            object
#  74   paleoage2            object
#  75   paleolng2            float64
#  76   paleolat2            float64
#  77   paleomodel3          object
#  78   geoplate3            object
#  79   paleoage3            object
#  80   paleolng3            float64
#  81   paleolat3            float64
#  82   formation            object
#  83   stratgroup           object
#  84   member               object
#  85   formation.1          object
#  86   stratgroup.1         object
#  87   member.1             object
#  88   stratscale           object
#  89   zone                 object
#  90   localsection         object
#  91   localbed             object
#  92   localbedunit         object
#  93   localorder           object
#  94   regionalsection      object
#  95   regionalbed          float64
#  96   regionalbedunit      object
#  97   regionalorder        object
#  98   stratcomments        object
#  99   lithdescript         object
#  100  lithology1           object
#  101  lithadj1             object
#  102  lithification1       object
#  103  minor_lithology1     object
#  104  fossilsfrom1         object
#  105  lithology2           object
#  106  lithadj2             object
#  107  lithification2       object
#  108  minor_lithology2     object
#  109  fossilsfrom2         object
#  110  lithdescript.1       object
#  111  lithology1.1         object
#  112  lithadj1.1           object
#  113  lithification1.1     object
#  114  minor_lithology1.1   object
#  115  fossilsfrom1.1       object
#  116  lithology2.1         object
#  117  lithadj2.1           object
#  118  lithification2.1     object
#  119  minor_lithology2.1   object
#  120  fossilsfrom2.1       object
#  121  environment          object
#  122  tectonic_setting     object
#  123  geology_comments     object
#  124  time_bins            object
#  125  time_contain         object
#  126  time_major           object
#  127  time_buffer          object
#  128  time_overlap         object
#  129  collection_type      object
#  130  collection_methods   object
#  131  museum               object
#  132  collection_coverage  object
#  133  collection_size      object
#  134  rock_censused        object
#  135  collectors           object
#  136  collection_dates     object
#  137  collection_comments  object
#  138  taxonomy_comments    object
#  139  primary_reference    object
#  140  authorizer_no        int64
#  141  enterer_no           int64
#  142  modifier_no          int64
#  143  authorizer           object
#  144  enterer              object
#  145  modifier             object
# dtypes: float64(16), int64(7), object(123)
# memory usage: 12.6+ MB
# None

# %% [markdown]
# Como grupo fuimos viendo manualmente que columnas nos servirian para poder responder las preguntas planteadas en la propuesta inicial, y llegamos a un concenso de elegir las siguientes 19 columnas como base para poder responder estas.

# %%
columns = [
    'species_name',
    'occurrence_no',
    'accepted_name',
    'accepted_rank',
    'early_interval',
    'late_interval',
    'max_ma',
    'min_ma',
    'phylum',
    'class',
    'order',
    'family',
    'genus',
    'lat',
    'lng',
    'diet',
    'geogscale',
    'regionalsection',
    'life_habit'
]

df_chile_new = chile_df[columns].copy()
df_argentina_new = argentina_df[columns].copy()
df_antartica_new = antartica_df[columns].copy()

# %%
df_chile_new
# Out:
#      species_name  occurrence_no            accepted_name accepted_rank  \
# 0       ceciliana          16417               Leionucula         genus
# 1      amuriensis          16418                 Nuculana         genus
# 2     cuneiformis          16419                 Nuculana         genus
# 3     levitestata          16420                   Yoldia         genus
# 4         pencana          16421                Neiloides         genus
# ...           ...            ...                      ...           ...
# 9476          sp.        1659402                   Ostrea         genus
# 9477   antarctica        1659403     Cucullaea antarctica       species
# 9478          sp.        1659404                   Nucula         genus
# 9479   saladensis        1660104  Micrauchenia saladensis       species
# 9480       indet.        1662256             Tracheophyta   superphylum
#
#            early_interval late_interval  max_ma  min_ma        phylum  \
# 0           Maastrichtian           NaN   72.10  66.000      Mollusca
# 1           Maastrichtian           NaN   72.10  66.000      Mollusca
# 2           Maastrichtian           NaN   72.10  66.000      Mollusca
# 3           Maastrichtian           NaN   72.10  66.000      Mollusca
# 4           Maastrichtian           NaN   72.10  66.000      Mollusca
# ...                   ...           ...     ...     ...           ...
# 9476             Turonian     Campanian   93.90  72.100      Mollusca
# 9477             Turonian     Campanian   93.90  72.100      Mollusca
# 9478             Turonian     Campanian   93.90  72.100      Mollusca
# 9479            Tortonian     Messinian   11.63   5.333      Chordata
# 9480  Early Maastrichtian           NaN   72.10  66.000  Tracheophyta
#
#          class             order               family         genus  \
# 0     Bivalvia          Nuculida            Nuculidae    Leionucula
# 1     Bivalvia        Nuculanida          Nuculanidae      Nuculana
# 2     Bivalvia        Nuculanida          Nuculanidae      Nuculana
# 3     Bivalvia        Nuculanida            Yoldiidae        Yoldia
# 4     Bivalvia          Nuculida  NO_FAMILY_SPECIFIED     Neiloides
# ...        ...               ...                  ...           ...
# 9476  Bivalvia          Ostreida            Ostreidae        Ostrea
# 9477  Bivalvia            Arcida         Cucullaeidae     Cucullaea
# 9478  Bivalvia          Nuculida            Nuculidae        Nucula
# 9479  Mammalia  Panameriungulata      Macraucheniidae  Micrauchenia
# 9480       NaN               NaN                  NaN           NaN
#
#             lat        lng                               diet geogscale  \
# 0    -37.000000 -73.000000  deposit feeder, suspension feeder     basin
# 1    -37.000000 -73.000000  deposit feeder, suspension feeder     basin
# 2    -37.000000 -73.000000  deposit feeder, suspension feeder     basin
# 3    -37.000000 -73.000000                     deposit feeder     basin
# 4    -37.000000 -73.000000                     deposit feeder     basin
# ...         ...        ...                                ...       ...
# 9476 -50.884998 -72.625000                  suspension feeder       NaN
# 9477 -50.884998 -72.625000                  suspension feeder       NaN
# 9478 -50.884998 -72.625000  deposit feeder, suspension feeder       NaN
# 9479 -27.684723 -70.949997                          herbivore       NaN
# 9480 -50.711666 -72.541389                                NaN   outcrop
#
#       regionalsection  life_habit
# 0                 NaN    infaunal
# 1                 NaN    infaunal
# 2                 NaN    infaunal
# 3                 NaN    infaunal
# 4                 NaN    infaunal
# ...               ...         ...
# 9476              NaN   epifaunal
# 9477              NaN    infaunal
# 9478              NaN    infaunal
# 9479              NaN  scansorial
# 9480              NaN         NaN
#
# [9481 rows x 19 columns]

# %%
obtener_duplicados_chile = df_chile_new.duplicated(keep=False)
datos_duplicados_chile = df_chile_new[obtener_duplicados_chile]
datos_duplicados_chile
# Out:
# Empty DataFrame
# Columns: [species_name, occurrence_no, accepted_name, accepted_rank, early_interval, late_interval, max_ma, min_ma, phylum, class, order, family, genus, lat, lng, diet, geogscale, regionalsection, life_habit]
# Index: []

# %%
obtener_duplicados_argentina = df_argentina_new.duplicated(keep=False)
datos_duplicados_argentina = df_argentina_new[obtener_duplicados_argentina]
datos_duplicados_argentina
# Out:
# Empty DataFrame
# Columns: [species_name, occurrence_no, accepted_name, accepted_rank, early_interval, late_interval, max_ma, min_ma, phylum, class, order, family, genus, lat, lng, diet, geogscale, regionalsection, life_habit]
# Index: []

# %%
obtener_duplicados_antartica = df_antartica_new.duplicated(keep=False)
datos_duplicados_antartica = df_antartica_new[obtener_duplicados_antartica]
datos_duplicados_antartica
# Out:
# Empty DataFrame
# Columns: [species_name, occurrence_no, accepted_name, accepted_rank, early_interval, late_interval, max_ma, min_ma, phylum, class, order, family, genus, lat, lng, diet, geogscale, regionalsection, life_habit]
# Index: []

# %%
df_chile_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9481 entries, 0 to 9480
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   species_name     9481 non-null   object
#  1   occurrence_no    9481 non-null   int64
#  2   accepted_name    9343 non-null   object
#  3   accepted_rank    9343 non-null   object
#  4   early_interval   9481 non-null   object
#  5   late_interval    1605 non-null   object
#  6   max_ma           9481 non-null   float64
#  7   min_ma           9481 non-null   float64
#  8   phylum           9337 non-null   object
#  9   class            9292 non-null   object
#  10  order            9123 non-null   object
#  11  family           8914 non-null   object
#  12  genus            8574 non-null   object
#  13  lat              9481 non-null   float64
#  14  lng              9481 non-null   float64
#  15  diet             8749 non-null   object
#  16  geogscale        6426 non-null   object
#  17  regionalsection  0 non-null      float64
#  18  life_habit       8743 non-null   object
# dtypes: float64(5), int64(1), object(13)
# memory usage: 1.4+ MB

# %% [markdown]
# como podemos ver la columan 17

# %% [markdown]
# como todos los float e int estan completos

# %%
df_chile_new = df_chile_new.drop(columns = ["regionalsection"])

# %%
df_chile_new
# Out:
#      species_name  occurrence_no            accepted_name accepted_rank  \
# 0       ceciliana          16417               Leionucula         genus
# 1      amuriensis          16418                 Nuculana         genus
# 2     cuneiformis          16419                 Nuculana         genus
# 3     levitestata          16420                   Yoldia         genus
# 4         pencana          16421                Neiloides         genus
# ...           ...            ...                      ...           ...
# 9476          sp.        1659402                   Ostrea         genus
# 9477   antarctica        1659403     Cucullaea antarctica       species
# 9478          sp.        1659404                   Nucula         genus
# 9479   saladensis        1660104  Micrauchenia saladensis       species
# 9480       indet.        1662256             Tracheophyta   superphylum
#
#            early_interval late_interval  max_ma  min_ma        phylum  \
# 0           Maastrichtian           NaN   72.10  66.000      Mollusca
# 1           Maastrichtian           NaN   72.10  66.000      Mollusca
# 2           Maastrichtian           NaN   72.10  66.000      Mollusca
# 3           Maastrichtian           NaN   72.10  66.000      Mollusca
# 4           Maastrichtian           NaN   72.10  66.000      Mollusca
# ...                   ...           ...     ...     ...           ...
# 9476             Turonian     Campanian   93.90  72.100      Mollusca
# 9477             Turonian     Campanian   93.90  72.100      Mollusca
# 9478             Turonian     Campanian   93.90  72.100      Mollusca
# 9479            Tortonian     Messinian   11.63   5.333      Chordata
# 9480  Early Maastrichtian           NaN   72.10  66.000  Tracheophyta
#
#          class             order               family         genus  \
# 0     Bivalvia          Nuculida            Nuculidae    Leionucula
# 1     Bivalvia        Nuculanida          Nuculanidae      Nuculana
# 2     Bivalvia        Nuculanida          Nuculanidae      Nuculana
# 3     Bivalvia        Nuculanida            Yoldiidae        Yoldia
# 4     Bivalvia          Nuculida  NO_FAMILY_SPECIFIED     Neiloides
# ...        ...               ...                  ...           ...
# 9476  Bivalvia          Ostreida            Ostreidae        Ostrea
# 9477  Bivalvia            Arcida         Cucullaeidae     Cucullaea
# 9478  Bivalvia          Nuculida            Nuculidae        Nucula
# 9479  Mammalia  Panameriungulata      Macraucheniidae  Micrauchenia
# 9480       NaN               NaN                  NaN           NaN
#
#             lat        lng                               diet geogscale  \
# 0    -37.000000 -73.000000  deposit feeder, suspension feeder     basin
# 1    -37.000000 -73.000000  deposit feeder, suspension feeder     basin
# 2    -37.000000 -73.000000  deposit feeder, suspension feeder     basin
# 3    -37.000000 -73.000000                     deposit feeder     basin
# 4    -37.000000 -73.000000                     deposit feeder     basin
# ...         ...        ...                                ...       ...
# 9476 -50.884998 -72.625000                  suspension feeder       NaN
# 9477 -50.884998 -72.625000                  suspension feeder       NaN
# 9478 -50.884998 -72.625000  deposit feeder, suspension feeder       NaN
# 9479 -27.684723 -70.949997                          herbivore       NaN
# 9480 -50.711666 -72.541389                                NaN   outcrop
#
#       life_habit
# 0       infaunal
# 1       infaunal
# 2       infaunal
# 3       infaunal
# 4       infaunal
# ...          ...
# 9476   epifaunal
# 9477    infaunal
# 9478    infaunal
# 9479  scansorial
# 9480         NaN
#
# [9481 rows x 18 columns]

# %%
df_argentina_new = df_argentina_new.drop(columns = ["regionalsection"])

# %%
df_argentina_new
# Out:
#           species_name  occurrence_no                 accepted_name  \
# 0                  sp.          17744                      Nuculana
# 1               rocana          17745                     Cucullaea
# 2           feruglioli          17746                   Glycymerita
# 3                  sp.          17747                   Glycymerita
# 4      mechanquilensis          17748                    Inoceramus
# ...                ...            ...                           ...
# 31876         cretacea        1664301         Guembelitria cretacea
# 31877     macrocephala        1664302  Rugoglobigerina macrocephala
# 31878        excellens        1664303           Cythereis excellens
# 31879          venusta        1664304       Petalocythereis venusta
# 31880       patagonica        1664305           Bradleya patagonica
#
#       accepted_rank early_interval late_interval  max_ma  min_ma  \
# 0             genus  Maastrichtian           NaN    72.1    66.0
# 1             genus  Maastrichtian           NaN    72.1    66.0
# 2             genus  Maastrichtian           NaN    72.1    66.0
# 3             genus  Maastrichtian           NaN    72.1    66.0
# 4             genus  Maastrichtian           NaN    72.1    66.0
# ...             ...            ...           ...     ...     ...
# 31876       species  Maastrichtian           NaN    72.1    66.0
# 31877       species  Maastrichtian           NaN    72.1    66.0
# 31878       species  Maastrichtian           NaN    72.1    66.0
# 31879       species  Maastrichtian           NaN    72.1    66.0
# 31880       species  Maastrichtian           NaN    72.1    66.0
#
#              phylum               class         order             family  \
# 0          Mollusca            Bivalvia    Nuculanida        Nuculanidae
# 1          Mollusca            Bivalvia        Arcida       Cucullaeidae
# 2          Mollusca            Bivalvia        Arcida     Glycymerididae
# 3          Mollusca            Bivalvia        Arcida     Glycymerididae
# 4          Mollusca            Bivalvia     Myalinida       Inoceramidae
# ...             ...                 ...           ...                ...
# 31876  Foraminifera  NO_CLASS_SPECIFIED  Foraminifera    Guembelitriidae
# 31877  Foraminifera  NO_CLASS_SPECIFIED  Foraminifera   Globotruncanidae
# 31878    Arthropoda           Ostracoda    Podocopida  Trachyleberididae
# 31879    Arthropoda           Ostracoda    Podocopida  Trachyleberididae
# 31880    Arthropoda           Ostracoda    Podocopida   Thaerocytheridae
#
#                  genus        lat        lng  \
# 0             Nuculana -39.000000 -69.000000
# 1            Cucullaea -39.000000 -69.000000
# 2          Glycymerita -39.000000 -69.000000
# 3          Glycymerita -39.000000 -69.000000
# 4           Inoceramus -39.000000 -69.000000
# ...                ...        ...        ...
# 31876     Guembelitria -38.099998 -68.383331
# 31877  Rugoglobigerina -38.099998 -68.383331
# 31878        Cythereis -38.099998 -68.383331
# 31879  Petalocythereis -38.099998 -68.383331
# 31880         Bradleya -38.099998 -68.383331
#
#                                     diet geogscale     life_habit
# 0      deposit feeder, suspension feeder     basin       infaunal
# 1                      suspension feeder     basin       infaunal
# 2                      suspension feeder     basin  semi-infaunal
# 3                      suspension feeder     basin  semi-infaunal
# 4                      suspension feeder     basin      epifaunal
# ...                                  ...       ...            ...
# 31876                           omnivore       NaN  semi-infaunal
# 31877                           omnivore       NaN  semi-infaunal
# 31878                detritivore, grazer       NaN      epifaunal
# 31879                detritivore, grazer       NaN      epifaunal
# 31880                detritivore, grazer       NaN      epifaunal
#
# [31881 rows x 18 columns]

# %%
df_antartica_new = df_antartica_new.drop(columns = ["regionalsection"])

# %%
df_antartica_new
# Out:
#         species_name  occurrence_no                   accepted_name  \
# 0           rossiana          16484                         Solemya
# 1         suboblonga          16485  Nucula (Leionucula) suboblonga
# 2      nordenskjoldi          16486                 Nordenskjoeldia
# 3           oliveroi          16487                             NaN
# 4         antarctica          16488            Cucullaea antarctica
# ...              ...            ...                             ...
# 11306         indet.        1662164                    Mosasauridae
# 11307            sp.        1662165                     Moanasaurus
# 11308         indet.        1662166                    Mosasaurinae
# 11309            sp.        1662168                    Tylosaurinae
# 11310            sp.        1662169                         Leiodon
#
#       accepted_rank      early_interval late_interval  max_ma  min_ma  \
# 0             genus       Maastrichtian           NaN    72.1    66.0
# 1           species       Maastrichtian           NaN    72.1    66.0
# 2             genus       Maastrichtian           NaN    72.1    66.0
# 3               NaN       Maastrichtian           NaN    72.1    66.0
# 4           species       Maastrichtian           NaN    72.1    66.0
# ...             ...                 ...           ...     ...     ...
# 11306        family  Late Maastrichtian           NaN    72.1    66.0
# 11307         genus  Late Maastrichtian           NaN    72.1    66.0
# 11308     subfamily  Late Maastrichtian           NaN    72.1    66.0
# 11309     subfamily  Late Maastrichtian           NaN    72.1    66.0
# 11310         genus  Late Maastrichtian           NaN    72.1    66.0
#
#          phylum     class      order             family            genus  \
# 0      Mollusca  Bivalvia  Solemyida         Solemyidae          Solemya
# 1      Mollusca  Bivalvia   Nuculida          Nuculidae       Leionucula
# 2      Mollusca  Bivalvia     Arcida  Parallelodontidae  Nordenskjoeldia
# 3           NaN       NaN        NaN                NaN              NaN
# 4      Mollusca  Bivalvia     Arcida       Cucullaeidae        Cucullaea
# ...         ...       ...        ...                ...              ...
# 11306  Chordata  Reptilia   Squamata       Mosasauridae              NaN
# 11307  Chordata  Reptilia   Squamata       Mosasauridae      Moanasaurus
# 11308  Chordata  Reptilia   Squamata       Mosasauridae              NaN
# 11309  Chordata  Reptilia   Squamata       Mosasauridae              NaN
# 11310  Chordata  Reptilia   Squamata       Mosasauridae          Leiodon
#
#              lat        lng                               diet geogscale  \
# 0     -64.000000 -57.000000     deposit feeder, chemosymbiotic     basin
# 1     -64.000000 -57.000000  deposit feeder, suspension feeder     basin
# 2     -64.000000 -57.000000                  suspension feeder     basin
# 3     -64.000000 -57.000000                                NaN     basin
# 4     -64.000000 -57.000000                  suspension feeder     basin
# ...          ...        ...                                ...       ...
# 11306 -64.286942 -56.836945                          carnivore       NaN
# 11307 -64.292221 -56.800835                          carnivore       NaN
# 11308 -64.292221 -56.800835                          carnivore       NaN
# 11309 -64.286942 -56.836945                          carnivore       NaN
# 11310 -63.884998 -57.584442                          carnivore       NaN
#
#                 life_habit
# 0            deep infaunal
# 1                 infaunal
# 2      low-level epifaunal
# 3                      NaN
# 4                 infaunal
# ...                    ...
# 11306              aquatic
# 11307              aquatic
# 11308              aquatic
# 11309              aquatic
# 11310              aquatic
#
# [11311 rows x 18 columns]
